# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import scipy

# %% [markdown]
# ## Create random data from specific stats

# %% [markdown]
# ## Calculate the cov from the stats above

# %%
mean_wq = 1.3596107
std_wq = 0.224064
mean_flow = 2.969030
std_flow = 0.224120

# %% [markdown]
# For a covariance matrix [[6, -3], [-3, 3.5]]. The expected variances of the first and second components of the sample are 6 and 3.5, respectively, and the expected correlation coefficient is -3/sqrt(6*3.5) ≈ -0.65465.

# %%
corr = 0.6
x = 0.6 * np.sqrt(std_wq**2 * std_flow**2)
cov = [[std_wq**2, x], [x, std_flow**2]]

# %%
cov
# Out:
# [[0.050204676096, 0.030130334208], [0.030130334208, 0.0502297744]]

# %%
pts = np.random.multivariate_normal([mean_wq, mean_flow], cov, size=10000)
pts = pd.DataFrame(pts, columns=["Quality", "Flow"])

# %% [markdown]
# ## Visualise

# %%
print(
    "Mean\n", pts.mean(axis=0),
    "\nStd\n", pts.std(axis=0), 
    "\nCovariance\n", np.cov(pts.T), 
    "\nCorrelation\n", np.corrcoef(pts.T)[0, 1]
)
# Out:
# Mean
#  Quality    1.361788
# Flow       2.970455
# dtype: float64
# Std
#  Quality    0.223927
# Flow       0.223163
# dtype: float64
# Covariance
#  [[0.05014309 0.03016895]
#  [0.03016895 0.04980185]]
# Correlation
#  0.6037149798159489

# %%
g = sns.jointplot(
    x="Quality",
    y="Flow",
    data=pts,
    kind="reg",
    truncate=False,
    height=5,
    scatter_kws={"alpha": 0.1},
)

# %%
pts = np.exp(pts)

# %%
print(
    "Mean\n", pts.mean(axis=0),
    "\nStd\n", pts.std(axis=0), 
    "\nCovariance\n", np.cov(pts.T), 
    "\nCorrelation\n", np.corrcoef(pts.T)[0, 1]
)
# Out:
# Mean
#  Quality     4.001919
# Flow       19.992214
# dtype: float64
# Std
#  Quality    0.902711
# Flow       4.514205
# dtype: float64
# Covariance
#  [[ 0.81488716  2.43246147]
#  [ 2.43246147 20.37804426]]
# Correlation
#  0.596919796815729

# %%
g = sns.jointplot(
    x="Quality",
    y="Flow",
    data=pts,
    kind="reg",
    truncate=False,
    height=5,
    scatter_kws={"alpha": 0.1},
)
